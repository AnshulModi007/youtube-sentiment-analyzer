# %%
import pandas as pd

# %%
df = pd.read_csv("preprocessed_dataset.csv", encoding="latin-1")

# %%
df
# Out:
#        sentiment                                         clean_text  \
# 0              1             i would have responded if i were going
# 1              0          soo sad i will miss you here in san diego
# 2              0                             my boss is bullying me
# 3              0                      what interview leave me alone
# 4              0  sons of why couldn t they put them on the rele...
# ...          ...                                                ...
# 31010          0  its at 3 am im very tired but i cannot sleep b...
# 31011          2  all alone in this old house again thanks for t...
# 31012          0  i know what you mean my little dog is sinking ...
# 31013          2  _sutra what is your next youtube video gonna b...
# 31014          2                             omgssh ang cute ng bby
#
#        time_of_tweet  age  log_population  log_land_area  log_density
# 0                  0    0       17.477233      13.389120     4.110874
# ...

# %%
X_text = df[["clean_text"]]
y = df["sentiment"]

# %%
TEXT_COL = "clean_text"

CAT_COLS = [
    "time_of_tweet",
    "age"
]

NUM_COLS = [
    "log_population",
    "log_land_area",
    "log_density"
]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer


TfidfVectorizer(
    analyzer="char_wb",
    ngram_range=(3, 5),
    min_df=2,
    max_df=0.95,
    max_features=50000,
    sublinear_tf=True
)
# Out:
# TfidfVectorizer(analyzer='char_wb', max_df=0.95, max_features=50000, min_df=2,
#                 ngram_range=(3, 5), sublinear_tf=True)

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.metrics import classification_report

# %%
X = df["clean_text"].astype(str)
y = df["sentiment"]

# %%
pipeline = Pipeline([
    ("tfidf", TfidfVectorizer(
        analyzer="char_wb",
        ngram_range=(3, 5),
        min_df=2,
        max_df=0.95,
        sublinear_tf=True
    )),
    ("clf", LinearSVC(
        class_weight="balanced",
        random_state=42
    ))
])

# %%
param_grid = {
    "tfidf__max_features": [20000, 30000, 50000],
    "clf__C": [0.1, 0.5, 1.0, 2.0, 5.0]
}

# %%
cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

# %%
grid = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    scoring="f1_macro",
    cv=cv,
    n_jobs=-1,
    verbose=2
)

# %%
grid.fit(X, y)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('tfidf',
#                                         TfidfVectorizer(analyzer='char_wb',
#                                                         max_df=0.95, min_df=2,
#                                                         ngram_range=(3, 5),
#                                                         sublinear_tf=True)),
#                                        ('clf',
#                                         LinearSVC(class_weight='balanced',
#                                                   random_state=42))]),
#              n_jobs=-1,
#              param_grid={'clf__C': [0.1, 0.5, 1.0, 2.0, 5.0],
#                          'tfidf__max_features': [20000, 30000, 50000]},
#              scoring='f1_macro', verbose=2)

# %%
print("Best F1-macro:", grid.best_score_)
print("Best parameters:", grid.best_params_)
# Out:
# Best F1-macro: 0.7189359526922756
# Best parameters: {'clf__C': 0.1, 'tfidf__max_features': 20000}

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(
    analyzer="char_wb",
    ngram_range=(3, 5),
    min_df=2,
    max_df=0.95,
    sublinear_tf=True,
    max_features=20000
)

lr_pipeline = Pipeline([
    ("tfidf", tfidf),
    ("clf", LogisticRegression(
        solver="saga",
        max_iter=2000,
        class_weight="balanced",
        n_jobs=-1,
        multi_class="auto"
    ))
])

# %%
lr_pipeline.fit(X, y)
# Out:
# C:\Users\ANSHUL MODI\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.8. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(analyzer='char_wb', max_df=0.95,
#                                  max_features=20000, min_df=2,
#                                  ngram_range=(3, 5), sublinear_tf=True)),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=2000,
#                                     multi_class='auto', n_jobs=-1,
#                                     solver='saga'))])

# %%
lr_param_grid = {
    "tfidf__max_features": [20000, 30000, 50000],
    "clf__C": [0.1, 0.5, 1.0, 2.0, 5.0]
}

# %%
lr_grid = GridSearchCV(
    lr_pipeline,
    lr_param_grid,
    scoring="f1_macro",
    cv=cv,
    n_jobs=-1,
    verbose=2
)

lr_grid.fit(X, y)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# C:\Users\ANSHUL MODI\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.8. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('tfidf',
#                                         TfidfVectorizer(analyzer='char_wb',
#                                                         max_df=0.95,
#                                                         max_features=20000,
#                                                         min_df=2,
#                                                         ngram_range=(3, 5),
#                                                         sublinear_tf=True)),
#                                        ('clf',
# ...

# %%
print("LR Best F1:", lr_grid.best_score_)
print("LR Best Params:", lr_grid.best_params_)
# Out:
# LR Best F1: 0.7164888869471308
# LR Best Params: {'clf__C': 1.0, 'tfidf__max_features': 20000}

# %%
from sklearn.linear_model import SGDClassifier

sgd_pipeline = Pipeline([
    ("tfidf", tfidf),
    ("clf", SGDClassifier(
        class_weight="balanced",
        random_state=42
    ))
])

# %%
sgd_param_grid = {
    "tfidf__max_features": [20000, 30000, 50000],
    "clf__loss": ["hinge", "log_loss"],  # SVM-like vs LR-like
    "clf__alpha": [1e-4, 5e-4, 1e-3],
    "clf__max_iter": [1000, 2000]
}

# %%
sgd_grid = GridSearchCV(
    sgd_pipeline,
    sgd_param_grid,
    scoring="f1_macro",
    cv=cv,
    n_jobs=-1,
    verbose=2
)

sgd_grid.fit(X, y)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('tfidf',
#                                         TfidfVectorizer(analyzer='char_wb',
#                                                         max_df=0.95,
#                                                         max_features=20000,
#                                                         min_df=2,
#                                                         ngram_range=(3, 5),
#                                                         sublinear_tf=True)),
#                                        ('clf',
#                                         SGDClassifier(class_weight='balanced',
#                                                       random_state=42))]),
#              n_jobs=-1,
#              param_grid={'clf__alpha': [0.0001, 0.0005, 0.001],
# ...

# %%
print("SGD Best F1:", sgd_grid.best_score_)
print("SGD Best Params:", sgd_grid.best_params_)
# Out:
# SGD Best F1: 0.722655844055798
# SGD Best Params: {'clf__alpha': 0.0001, 'clf__loss': 'hinge', 'clf__max_iter': 1000, 'tfidf__max_features': 20000}

# %%
import pickle

pickle_model_path = "fast_api_model.pkl"
with open(pickle_model_path, "wb") as f:
    pickle.dump(sgd_grid, f)
